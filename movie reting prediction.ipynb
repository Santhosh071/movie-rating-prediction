# %% [markdown]
# *IMPORTING IMPORTANT LIBRARIES*

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
import pandas as pd

# Assuming the correct encoding is 'latin-1' (common for older text files):
df_movie = pd.read_csv("/content/movies.dat", sep="::", engine="python", encoding="latin-1")

# Rest of your code remains the same:
df_movie.columns = ['MovieIDs', 'MovieName', 'Category']
df_movie.dropna(inplace=True)
df_movie.head()
# Out:
#    MovieIDs                           MovieName                      Category
# 0         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 1         3             Grumpier Old Men (1995)                Comedy|Romance
# 2         4            Waiting to Exhale (1995)                  Comedy|Drama
# 3         5  Father of the Bride Part II (1995)                        Comedy
# 4         6                         Heat (1995)         Action|Crime|Thriller

# %%
# Movie

#Data acquisition of the rating dataset
df_rating = pd.read_csv("/content/ratings.dat", sep="::", engine="python")
df_rating.columns =['ID','MovieID','Ratings','TimeStamp']
df_rating.dropna(inplace=True)
df_rating.head()
# Out:
#    ID  MovieID  Ratings  TimeStamp
# 0   1      661        3  978302109
# 1   1      914        3  978301968
# 2   1     3408        4  978300275
# 3   1     2355        5  978824291
# 4   1     1197        3  978302268

# %%
df_movie.describe()
# Out:
#           MovieIDs
# count  3882.000000
# mean   1986.560793
# std    1146.483260
# min       2.000000
# 25%     983.250000
# 50%    2010.500000
# 75%    2980.750000
# max    3952.000000

# %%
# Rating

#Data acquisition of the users dataset
df_user = pd.read_csv("/content/users.dat",sep="::",engine="python")
df_user.columns =['UserID','Gender','Age','Occupation','Zip-code']
df_user.dropna(inplace=True)
df_user.head()
# Out:
#    UserID Gender  Age  Occupation Zip-code
# 0       2      M   56          16    70072
# 1       3      M   25          15    55117
# 2       4      M   45           7    02460
# 3       5      M   25          20    55455
# 4       6      F   50           9    55117

# %%
df = pd.concat([df_movie, df_rating,df_user], axis=1)
df.head()
# Out:
#    MovieIDs                           MovieName                      Category  \
# 0       2.0                      Jumanji (1995)  Adventure|Children's|Fantasy
# 1       3.0             Grumpier Old Men (1995)                Comedy|Romance
# 2       4.0            Waiting to Exhale (1995)                  Comedy|Drama
# 3       5.0  Father of the Bride Part II (1995)                        Comedy
# 4       6.0                         Heat (1995)         Action|Crime|Thriller
#
#    ID  MovieID  Ratings  TimeStamp  UserID Gender   Age  Occupation Zip-code
# 0   1      661        3  978302109     2.0      M  56.0        16.0    70072
# 1   1      914        3  978301968     3.0      M  25.0        15.0    55117
# 2   1     3408        4  978300275     4.0      M  45.0         7.0    02460
# 3   1     2355        5  978824291     5.0      M  25.0        20.0    55455
# 4   1     1197        3  978302268     6.0      F  50.0         9.0    55117

# %%
df_ratings.shape
# Out:
# (1000208, 4)

# %%
df_ratings.describe()
# Out:
#                   1          1193             5     978300760
# count  1.000208e+06  1.000208e+06  1.000208e+06  1.000208e+06
# mean   3.024515e+03  1.865541e+03  3.581563e+00  9.722437e+08
# std    1.728411e+03  1.096041e+03  1.117102e+00  1.215256e+07
# min    1.000000e+00  1.000000e+00  1.000000e+00  9.567039e+08
# 25%    1.506000e+03  1.030000e+03  3.000000e+00  9.653026e+08
# 50%    3.070000e+03  1.835000e+03  4.000000e+00  9.730180e+08
# 75%    4.476000e+03  2.770000e+03  4.000000e+00  9.752209e+08
# max    6.040000e+03  3.952000e+03  5.000000e+00  1.046455e+09
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14['1'].plot(kind='hist', bins=20, title='1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['1193'].plot(kind='hist', bins=20, title='1193')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['5'].plot(kind='hist', bins=20, title='5')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['978300760'].plot(kind='hist', bins=20, title='978300760')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_18.plot(kind='scatter', x='1', y='1193', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19.plot(kind='scatter', x='1193', y='5', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_20.plot(kind='scatter', x='5', y='978300760', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_21['1'].plot(kind='line', figsize=(8, 4), title='1')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22['1193'].plot(kind='line', figsize=(8, 4), title='1193')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23['5'].plot(kind='line', figsize=(8, 4), title='5')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['978300760'].plot(kind='line', figsize=(8, 4), title='978300760')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df_ratings.isna().sum()
# Out:
# 1            0
# 1193         0
# 5            0
# 978300760    0
# dtype: int64

# %% [markdown]
# *DOWNLOADING DATASETS*
#
#
# > **Users_data**

# %%
# User

#Data acquisition of the users dataset
df_users=pd.read_csv("/content/users.dat", sep="::", engine="python")
df_users.dropna(inplace=True)
df_users.head(10)
# Out:
#     1  F  1.1  10  48067
# 0   2  M   56  16  70072
# 1   3  M   25  15  55117
# 2   4  M   45   7  02460
# 3   5  M   25  20  55455
# 4   6  F   50   9  55117
# 5   7  M   35   1  06810
# 6   8  M   25  12  11413
# 7   9  M   25  17  61614
# 8  10  F   35   1  95370
# 9  11  F   25   1  04093

# %%
df_users.shape
# Out:
# (6039, 5)

# %%
df_users.describe()
# Out:
#                  1          1.1           10
# count  6039.000000  6039.000000  6039.000000
# mean   3021.000000    30.644146     8.146547
# std    1743.453469    12.891387     6.329991
# min       2.000000     1.000000     0.000000
# 25%    1511.500000    25.000000     3.000000
# 50%    3021.000000    25.000000     7.000000
# 75%    4530.500000    35.000000    14.000000
# max    6040.000000    56.000000    20.000000

# %%
df = pd.concat([df_movie, df_rating,df_user], axis=1)
df.head()
# Out:
#    MovieIDs                           MovieName                      Category  \
# 0       2.0                      Jumanji (1995)  Adventure|Children's|Fantasy
# 1       3.0             Grumpier Old Men (1995)                Comedy|Romance
# 2       4.0            Waiting to Exhale (1995)                  Comedy|Drama
# 3       5.0  Father of the Bride Part II (1995)                        Comedy
# 4       6.0                         Heat (1995)         Action|Crime|Thriller
#
#    ID  MovieID  Ratings  TimeStamp  UserID Gender   Age  Occupation Zip-code
# 0   1      661        3  978302109     2.0      M  56.0        16.0    70072
# 1   1      914        3  978301968     3.0      M  25.0        15.0    55117
# 2   1     3408        4  978300275     4.0      M  45.0         7.0    02460
# 3   1     2355        5  978824291     5.0      M  25.0        20.0    55455
# 4   1     1197        3  978302268     6.0      F  50.0         9.0    55117

# %%
df_users.isna().sum()
# Out:
# 1        0
# F        0
# 1.1      0
# 10       0
# 48067    0
# dtype: int64

# %%
df_data=pd.concat([df_movie,df_ratings,df_users],axis=1)
df_data.dropna()
df_data.head(10)
# Out:
#    MovieIDs                           MovieName                      Category  \
# 0       2.0                      Jumanji (1995)  Adventure|Children's|Fantasy
# 1       3.0             Grumpier Old Men (1995)                Comedy|Romance
# 2       4.0            Waiting to Exhale (1995)                  Comedy|Drama
# 3       5.0  Father of the Bride Part II (1995)                        Comedy
# 4       6.0                         Heat (1995)         Action|Crime|Thriller
# 5       7.0                      Sabrina (1995)                Comedy|Romance
# 6       8.0                 Tom and Huck (1995)          Adventure|Children's
# 7       9.0                 Sudden Death (1995)                        Action
# 8      10.0                    GoldenEye (1995)     Action|Adventure|Thriller
# 9      11.0      American President, The (1995)          Comedy|Drama|Romance
#
#    1  1193  5  978300760     1  F   1.1    10  48067
# 0  1   661  3  978302109   2.0  M  56.0  16.0  70072
# 1  1   914  3  978301968   3.0  M  25.0  15.0  55117
# 2  1  3408  4  978300275   4.0  M  45.0   7.0  02460
# 3  1  2355  5  978824291   5.0  M  25.0  20.0  55455
# 4  1  1197  3  978302268   6.0  F  50.0   9.0  55117
# 5  1  1287  5  978302039   7.0  M  35.0   1.0  06810
# 6  1  2804  5  978300719   8.0  M  25.0  12.0  11413
# 7  1   594  4  978302268   9.0  M  25.0  17.0  61614
# 8  1   919  4  978301368  10.0  F  35.0   1.0  95370
# 9  1   595  5  978824268  11.0  F  25.0   1.0  04093

# %%
#Visualize user age distribution
df['Age'].value_counts().plot(kind='barh',alpha=0.7,figsize=(10,10))
plt.show()

# %%
df.Age.plot.hist(bins=25)
plt.title("Distribution of users' ages")
plt.ylabel('count of users')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
labels = ['0-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79']
df['age_group'] = pd.cut(df.Age, range(0, 81, 10), right=False, labels=labels)
df[['Age', 'age_group']].drop_duplicates()[:10]
# Out:
#        Age age_group
# 0     56.0     50-59
# 1     25.0     20-29
# 2     45.0     40-49
# 4     50.0     50-59
# 5     35.0     30-39
# 16    18.0     10-19
# 17     1.0       0-9
# 6039   NaN       NaN

# %%
#Visualize overall rating by users
df['Ratings'].value_counts().plot(kind='bar',alpha=0.7,figsize=(10,10))
plt.show()

# %%
groupedby_movieName = df.groupby('MovieName')
groupedby_rating = df.groupby('Ratings')
groupedby_uid = df.groupby('UserID')
#groupedby_age = df.loc[most_50.index].groupby(['MovieName', 'age_group'])

# %%
movies = df.groupby('MovieName').size().sort_values(ascending=True)[:1000]
print(movies)
# Out:
# MovieName
# $1,000,000 Duck (1971)                   1
# Only Angels Have Wings (1939)            1
# Only You (1994)                          1
# Open Season (1996)                       1
# Open Your Eyes (Abre los ojos) (1997)    1
#                                         ..
# Toy Story 2 (1999)                       1
# Toys (1992)                              1
# Total Eclipse (1995)                     1
# Trading Places (1983)                    1
# Tom & Viv (1994)                         1
# Length: 1000, dtype: int64

# %%
ToyStory_data = groupedby_movieName.get_group('Toy Story 2 (1999)')
ToyStory_data.shape
# Out:
# (1, 13)

# %%
#Find and visualize the user rating of the movie “Toy Story”
plt.figure(figsize=(10,10))
plt.scatter(ToyStory_data['MovieName'],ToyStory_data['Ratings'])
plt.title('Plot showing  the user rating of the movie “Toy Story”')
plt.show()

# %%
#Find and visualize the viewership of the movie “Toy Story” by age group
ToyStory_data[['MovieName','age_group']]#Find and visualize the top 25 movies by viewership rating
top_25 = df[25:]
top_25['Ratings'].value_counts().plot(kind='barh',alpha=0.6,figsize=(7,7))
plt.show()

# %%
#First 500 extracted records
first_500 = df[500:]
first_500.dropna(inplace=True)
# Out:
# <ipython-input-71-7595af47d31a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_500.dropna(inplace=True)

# %%
#Use the following features:movie id,age,occupation
features = first_500[['MovieID','Age','Occupation']].values

# %%
#Use rating as label
labels = first_500[['Ratings']].values

# %%
#Create train and test data set
train, test, train_labels, test_labels = train_test_split(features,labels,test_size=0.33,random_state=42)

# %%
#Create a histogram for movie
df.Age.plot.hist(bins=25)
plt.title("Movie & Rating")
plt.ylabel('MovieID')
plt.xlabel('Ratings')
# Out:
# Text(0.5, 0, 'Ratings')

# %%
#Create a histogram for occupation
df.Age.plot.hist(bins=25)
plt.title("Occupation & Rating")
plt.ylabel('Occupation')
plt.xlabel('Ratings')
# Out:
# Text(0.5, 0, 'Ratings')

# %%
# Support Vector Machines

svc = SVC()
svc.fit(train, train_labels)
Y_pred = svc.predict(test)
acc_svc = round(svc.score(train, train_labels) * 100, 2)
acc_svc
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 32.94

# %%
# K Nearest Neighbors Classifier

knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(train, train_labels)
Y_pred = knn.predict(test)
acc_knn = round(knn.score(train, train_labels) * 100, 2)
acc_knn
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 57.75

# %%
# Gaussian Naive Bayes

gaussian = GaussianNB()
gaussian.fit(train, train_labels)
Y_pred = gaussian.predict(test)
acc_gaussian = round(gaussian.score(train, train_labels) * 100, 2)
acc_gaussian
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 32.23

# %%
# Perceptron

perceptron = Perceptron()
perceptron.fit(train, train_labels)
Y_pred = perceptron.predict(test)
acc_perceptron = round(perceptron.score(train, train_labels) * 100, 2)
acc_perceptron
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 28.61

# %%
# Linear SVC

linear_svc = LinearSVC()
linear_svc.fit(train, train_labels)
Y_pred = linear_svc.predict(test)
acc_linear_svc = round(linear_svc.score(train, train_labels) * 100, 2)
acc_linear_svc
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 28.74

# %%
# Stochastic Gradient Descent

sgd = SGDClassifier()
sgd.fit(train, train_labels)
Y_pred = sgd.predict(test)
acc_sgd = round(sgd.score(train, train_labels) * 100, 2)
acc_sgd
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 11.52

# %%
# Decision Tree

decision_tree = DecisionTreeClassifier()
decision_tree.fit(train, train_labels)
Y_pred = decision_tree.predict(test)
acc_decision_tree = round(decision_tree.score(train, train_labels) * 100, 2)
acc_decision_tree
# Out:
# 98.54

# %%
#  Random Forest

random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(train, train_labels)
Y_pred = random_forest.predict(test)
random_forest.score(train, train_labels)
acc_random_forest = round(random_forest.score(train, train_labels) * 100, 2)
acc_random_forest
# Out:
# <ipython-input-84-e80714bd493d>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   random_forest.fit(train, train_labels)
# 98.54
